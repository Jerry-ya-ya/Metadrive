# %% [markdown]
# # MetaDrive PPO Project Notebook
#
# 這份 Notebook 是正式專案的簡化入口。主要訓練建議用 `.py` 檔執行，Notebook 用來檢查環境、預覽地圖與快速測試。

# %%
# %pip install -r ../requirements.txt

# %% [markdown]
# ## 檢查 CUDA

# %%
import torch
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))

# %% [markdown]
# ## 檢查 MetaDrive 環境

# %%
from metadrive import MetaDriveEnv

config = dict(use_render=False, map='XSSORC', traffic_density=0.0, horizon=1000)
env = MetaDriveEnv(config)
obs, info = env.reset()
print('Observation space:', env.observation_space)
print('Initial observation shape:', obs.shape)
print('Action space:', env.action_space)
env.close()

# %% [markdown]
# ## 快速訓練測試

# %%
# 在 Notebook 中只建議跑小步數確認流程。
# 正式長時間訓練請回到專案根目錄執行：python train.py --timesteps 500000

# !python ../train.py --timesteps 10000

# %% [markdown]
# ## 錄製影片

# %%
# !python ../record_video.py --steps 1000
